# %%
import pandas as pd

# %%
pd.read_csv('aerofit_treadmill.csv')
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
df = pd.read_csv('aerofit_treadmill.csv', usecols=['Product', 'Age', 'Gender'])

# %%
df
# Out:
#     Product  Age  Gender
# 0     KP281   18    Male
# 1     KP281   19    Male
# 2     KP281   19  Female
# 3     KP281   19    Male
# 4     KP281   20    Male
# ..      ...  ...     ...
# 175   KP781   40    Male
# 176   KP781   42    Male
# 177   KP781   45    Male
# 178   KP781   47    Male
# 179   KP781   48    Male
#
# [180 rows x 3 columns]

# %%
df1=pd.read_csv('aerofit_treadmill.csv',skiprows=10)

# %%
df1=pd.read_csv('aerofit_treadmill.csv',header=1)

# %%
df1
# Out:
#      KP281  18    Male  14     Single  3  4   29562  112
# 0    KP281  19    Male  15     Single  2  3   31836   75
# 1    KP281  19  Female  14  Partnered  4  3   30699   66
# 2    KP281  19    Male  12     Single  3  3   32973   85
# 3    KP281  20    Male  13  Partnered  4  2   35247   47
# 4    KP281  20  Female  14  Partnered  3  3   32973   66
# ..     ...  ..     ...  ..        ... .. ..     ...  ...
# 174  KP781  40    Male  21     Single  6  5   83416  200
# 175  KP781  42    Male  18     Single  5  4   89641  200
# 176  KP781  45    Male  16     Single  5  5   90886  160
# 177  KP781  47    Male  18  Partnered  4  5  104581  120
# 178  KP781  48    Male  18  Partnered  4  5   95508  180
#
# [179 rows x 9 columns]

# %%
df = pd.read_csv('aerofit_treadmill.csv')
df1 = df.iloc[3:6]

# %%
df1
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47
# 5   KP281   20  Female         14     Partnered      3        3   32973     66

# %%
df = pd.read_csv('aerofit_treadmill.csv')

# %%
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
df1=df.head(5)

# %%
df1
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47

# %%
df.shape
# Out:
# (180, 9)

# %%
df.columns
# Out:
# Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#        'Fitness', 'Income', 'Miles'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=180, step=1)

# %%
df.dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23660\1115469300.py in ?()
# ----> 1 df.dtype
#
# ~\PycharmProjects\myproject\pythonProject\.venv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
df.dtypes
# Out:
# Product          object
# Age               int64
# Gender           object
# Education         int64
# MaritalStatus    object
# Usage             int64
# Fitness           int64
# Income            int64
# Miles             int64
# dtype: object

# %%
df.age.unique
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23660\3129983913.py in ?()
# ----> 1 df.age.unique
#
# ~\PycharmProjects\myproject\pythonProject\.venv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'age'

# %%
df.Age.unique
# Out:
# <bound method Series.unique of 0      18
# 1      19
# 2      19
# 3      19
# 4      20
#        ..
# 175    40
# 176    42
# 177    45
# 178    47
# 179    48
# Name: Age, Length: 180, dtype: int64>

# %%
df.Gender.value_counts()
# Out:
# Gender
# Male      104
# Female     76
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
pd.read_csv('aerofit_treadmill.csv',skiprows=10,nrows=5)
# Out:
#    KP281  21  Female  15  Partnered  2  3  37521  85
# 0  KP281  22    Male  14     Single  3  3  36384  85
# 1  KP281  22  Female  14  Partnered  3  2  35247  66
# 2  KP281  22  Female  16     Single  4  3  36384  75
# 3  KP281  22  Female  14     Single  3  3  35247  75
# 4  KP281  23    Male  16  Partnered  3  1  38658  47

# %%
pd.read_csv('aerofit_treadmill.csv')
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
df1= df.iloc[10:14:3]

# %%
df1
# Out:
#    Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 10   KP281   22    Male         14        Single      3        3   36384
# 13   KP281   22  Female         14        Single      3        3   35247
#
#     Miles
# 10     85
# 13     75

# %%
df.sort_values(by='Age')
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 80    KP481   19    Male         14        Single      3        3   31836
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 78    KP281   47    Male         16     Partnered      4        3   56850
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 139   KP481   48    Male         16     Partnered      2        3   57987
# 179   KP781   48    Male         18     Partnered      4        5   95508
# 79    KP281   50  Female         16     Partnered      3        3   64809
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 80      64
# ...

# %%
df.sort_values(by=['Age','Income'],ascending=[True,False])
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 3     KP281   19    Male         12        Single      3        3   32973
# 1     KP281   19    Male         15        Single      2        3   31836
# 80    KP481   19    Male         14        Single      3        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 78    KP281   47    Male         16     Partnered      4        3   56850
# 179   KP781   48    Male         18     Partnered      4        5   95508
# 139   KP481   48    Male         16     Partnered      2        3   57987
# 79    KP281   50  Female         16     Partnered      3        3   64809
#
#      Miles
# 0      112
# 3       85
# 1       75
# 80      64
# 2       66
# ...

# %%
df.sort_values(by=['Age','Income'])
# Out:
# Product          180
# Age              180
# Gender           180
# Education        180
# MaritalStatus    180
# Usage            180
# Fitness          180
# Income           180
# Miles            180
# dtype: int64

# %%
df.groupby(['Product','Age']).count()
# Out:
#              Gender  Education  MaritalStatus  Usage  Fitness  Income  Miles
# Product Age
# KP281   18        1          1              1      1        1       1      1
#         19        3          3              3      3        3       3      3
#         20        2          2              2      2        2       2      2
#         21        4          4              4      4        4       4      4
#         22        4          4              4      4        4       4      4
# ...             ...        ...            ...    ...      ...     ...    ...
# KP781   40        1          1              1      1        1       1      1
#         42        1          1              1      1        1       1      1
#         45        1          1              1      1        1       1      1
#         47        1          1              1      1        1       1      1
#         48        1          1              1      1        1       1      1
#
# [68 rows x 7 columns]

# %%
df.groupby('Product')['Age'].agg(['mean','min'])
# Out:
#           mean  min
# Product
# KP281    28.55   18
# KP481    28.90   19
# KP781    29.10   22
